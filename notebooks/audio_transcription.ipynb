# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Initialize OpenAI client with API key from .env
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

with open(r"C:\Users\shels\Documents\wezareit el dakhleya\dakhleyaVideos\blue car swerving\blue car swerving.mp3", "rb") as f:
    transcript = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",
        file=f,
        language="ar",            # helps accuracy a bit
        response_format="text"    # or "json"
    )

print(transcript)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 5
#       2 client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
#       4 with open(r"C:\Users\shels\Documents\wezareit el dakhleya\dakhleyaVideos\blue car swerving\blue car swerving.mp3", "rb") as f:
# ----> 5     transcript = client.audio.transcriptions.create(
#       6         model="Whisper-1",
#       7         file=f,
#       8         language="ar",            # helps accuracy a bit
#       9         response_format="text"    # or "json"
#      10     )
#      12 print(transcript)
#
# File c:\Users\shels\Documents\wezareit el dakhleya\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\shels\Documents\wezareit el dakhleya\.venv\Lib\site-packages\openai\resources\audio\transcriptions.py:333, in Transcriptions.create(self, file, model, chunking_strategy, include, language, prompt, response_format, stream, temperature, timestamp_granularities, extra_headers, extra_query, extra_body, timeout)
#     329 # It should be noted that the actual Content-Type header that will be
#     330 # sent to the server will contain a `boundary` parameter, e.g.
#     331 # multipart/form-data; boundary=---abc--
#     332 extra_headers = {"Content-Type": "multipart/form-data", **(extra_headers or {})}
# --> 333 return self._post(  # type: ignore[return-value]
#     334     "/audio/transcriptions",
#     335     body=maybe_transform(
#     336         body,
#     337         transcription_create_params.TranscriptionCreateParamsStreaming
#     338         if stream
#     339         else transcription_create_params.TranscriptionCreateParamsNonStreaming,
#     340     ),
#     341     files=files,
#     342     options=make_request_options(
#     343         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     344     ),
#     345     cast_to=_get_response_format_type(response_format),
#     346     stream=stream or False,
#     347     stream_cls=Stream[TranscriptionStreamEvent],
#     348 )
#
# File c:\Users\shels\Documents\wezareit el dakhleya\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\shels\Documents\wezareit el dakhleya\.venv\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# NotFoundError: Error code: 404 - {'error': {'message': 'The model `Whisper-1` does not exist or you do not have access to it.', 'type': 'invalid_request_error', 'param': None, 'code': 'model_not_found'}}
