# %%
from dotenv import load_dotenv
import os
from openai import OpenAI

# Load environment variables from .env file
load_dotenv()
# Out:
# True

# %%
# Initialize OpenAI client with API key from .env
client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

with open(r"C:\Users\shels\Documents\wezareit el dakhleya\Gold thiefs.mp3", "rb") as f:
    transcript = client.audio.transcriptions.create(
        model="gpt-4o-mini-transcribe",
        file=f,
        language="ar",            # helps accuracy a bit
        response_format="text"    # or "json"
    )

print(transcript)
# Out:
# الاتنين دول حرامية، الاتنين دول سرقوا مننا خاتم في الفرع وطلعوا وجريوا ملامحهم واضحة جدا هنا. أبو دقن اللي ورا والمدامة اللي لابسة طرحة وبلازة صفرة دي الاتنين دول حرامية. هي هنا هتحطه في جيبها دلوقتي. هي حطته كده في جيبها خلاص. كده يحطته في جيبها. أجيبه برضو من زاوية تانية من الكاميرا تانية. هي بس استخلت ان احنا مشغولين مع زبون تاني دخل وانتهت الفرصة دي يعني وخدت الخاتم. أو هتاخده بيدها الشمال. هي هتاخده هتحطه دلوقتي في جيبها. ومن بجاح الراجل استغل ان احنا معنا ناس ومش عارف نعلع صوتنا ولا نعرف نجري وراه. قاعد يبجح ويعلي صوته وخب عضوه والمدام وطلعوا جري وركبوا مكانة. احنا كعامة سماريت سكر. أنا سماريت سكر أعملت حاجة. كمان هو سماريت سكر والله أعلم ده حقيقة ولا لا. ما أصلا يعني هم جايين بمكانة مش مترخصة أساسا ولا عليها نمر ولا عليها أي حاجة خالص. لا أعلم ممكن تكون مسروقة هي كمان. في الأول وفي الآخر الحمد لله أن هي جات على قد كده. ما حدش كبير قال أنه يحصل فيه موقف زي كده. دي الورقة اللي اتخذ منها الخاتم وده الخاتم اللي اتخذ. الحمد لله أن هي جات على قد كده. فنفضلكم بعد إذنكم شير. عشان على الأقل حقي يرجعلي أو هما بس. يعني أنا اللي ضايقني والله في الموقف بجاحهم إن هما حرمية وبيبجحوا فيا. فأنا يعني ياريت شير علشان على الأقل حقي يرجعلي.
