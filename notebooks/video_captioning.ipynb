# %%
# %pip install google-genai
# Out:
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached charset_normalizer-3.4.3-cp312-cp312-win_amd64.whl.metadata (37 kB)
# ...
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# ...
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached google_genai-1.42.0-py3-none-any.whl (236 kB)
# ...
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp312-cp312-win_amd64.whl (107 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# ...
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# ...
#
# ...

# %%
from google import genai
from google.genai import types
import os
# Configure the client with API key
api_key = "AIzaSyB37Oz2Bf4OQ4so2RIW7ELSybMFXl8--LM"

# %%
# Only for videos of size <20Mb
video_file_name = "C:\\Users\\shels\\Downloads\\dakhleya videos\\women brutality stairs\\women brutality stairs.mp4"
video_bytes = open(video_file_name, 'rb').read()

client = genai.Client(api_key=api_key)
response = client.models.generate_content(
    model='models/gemini-2.5-flash',
    contents=types.Content(
        parts=[
            types.Part(
                inline_data=types.Blob(data=video_bytes, mime_type='video/mp4')
            ),
            types.Part(text='Give a detailed description of the video and what happens in it')
        ]
    )
)

# %%
print(response.text)
# Out:
# The video, likely captured by a security camera, depicts a chaotic and violent incident taking place in a residential stairwell. The timestamp indicates "2025-08-17 00:35:59". Arabic text overlay at the top reads: "ايه اللي بيحصل ده !!!!" which translates to "What is happening?!"
#
# Here's a detailed description of the events:
#
# *   **00:00 - 00:01:** The scene begins with a man in a white short-sleeved top and dark pants, with long hair (possibly tied back), actively dragging another individual, who is wearing a long green garment (possibly a thobe or similar traditional wear), from the landing towards the top of the stairs. The person in green appears limp or is heavily resisting, being pulled by their upper body. Distressed shouts and sounds of struggle are immediately audible.
# ...
