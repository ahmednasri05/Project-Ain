# %%
# %pip install google-genai
# Out:
# Collecting google-genai
#   Downloading google_genai-1.42.0-py3-none-any.whl.metadata (45 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (4.11.0)
# Collecting google-auth<3.0.0,>=2.14.1 (from google-genai)
#   Downloading google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (2.12.0)
# Collecting requests<3.0.0,>=2.28.1 (from google-genai)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting tenacity<9.2.0,>=8.2.3 (from google-genai)
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# Collecting websockets<15.1.0,>=13.0.0 (from google-genai)
#   Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: idna>=2.8 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: sniffio>=1.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (1.3.1)
# Collecting cachetools<7.0,>=2.0.0 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Downloading cachetools-6.2.0-py3-none-any.whl.metadata (5.4 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Using cached pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth<3.0.0,>=2.14.1->google-genai)
#   Using cached rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: certifi in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from pydantic<3.0.0,>=2.0.0->google-genai) (0.4.2)
# Collecting charset_normalizer<4,>=2 (from requests<3.0.0,>=2.28.1->google-genai)
#   Using cached charset_normalizer-3.4.3-cp312-cp312-win_amd64.whl.metadata (37 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.28.1->google-genai)
#   Using cached urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.14.1->google-genai)
#   Using cached pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Using cached google_genai-1.42.0-py3-none-any.whl (236 kB)
# Downloading google_auth-2.41.1-py2.py3-none-any.whl (221 kB)
# Downloading cachetools-6.2.0-py3-none-any.whl (11 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.3-cp312-cp312-win_amd64.whl (107 kB)
# Using cached rsa-4.9.1-py3-none-any.whl (34 kB)
# Using cached tenacity-9.1.2-py3-none-any.whl (28 kB)
# Using cached urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading websockets-15.0.1-cp312-cp312-win_amd64.whl (176 kB)
# Using cached pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Using cached pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Installing collected packages: websockets, urllib3, tenacity, pyasn1, charset_normalizer, cachetools, rsa, requests, pyasn1-modules, google-auth, google-genai
#
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    ----------------------------------------  0/11 [websockets]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    --- ------------------------------------  1/11 [urllib3]
#    ------- --------------------------------  2/11 [tenacity]
#    ------- --------------------------------  2/11 [tenacity]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    ---------- -----------------------------  3/11 [pyasn1]
#    -------------- -------------------------  4/11 [charset_normalizer]
#    -------------- -------------------------  4/11 [charset_normalizer]
#    -------------- -------------------------  4/11 [charset_normalizer]
#    -------------- -------------------------  4/11 [charset_normalizer]
#    -------------- -------------------------  4/11 [charset_normalizer]
#    ------------------ ---------------------  5/11 [cachetools]
#    ------------------ ---------------------  5/11 [cachetools]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    --------------------- ------------------  6/11 [rsa]
#    ------------------------- --------------  7/11 [requests]
#    ------------------------- --------------  7/11 [requests]
#    ------------------------- --------------  7/11 [requests]
#    ------------------------- --------------  7/11 [requests]
#    ------------------------- --------------  7/11 [requests]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    ----------------------------- ----------  8/11 [pyasn1-modules]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    -------------------------------- -------  9/11 [google-auth]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ------------------------------------ --- 10/11 [google-genai]
#    ---------------------------------------- 11/11 [google-genai]
#
# Successfully installed cachetools-6.2.0 charset_normalizer-3.4.3 google-auth-2.41.1 google-genai-1.42.0 pyasn1-0.6.1 pyasn1-modules-0.4.2 requests-2.32.5 rsa-4.9.1 tenacity-9.1.2 urllib3-2.5.0 websockets-15.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install -U google-genai
# Out:
# Requirement already satisfied: google-genai in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (1.42.0)
# Collecting google-genai
#   Downloading google_genai-1.64.0-py3-none-any.whl.metadata (53 kB)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (4.11.0)
# Collecting google-auth<3.0.0,>=2.47.0 (from google-auth[requests]<3.0.0,>=2.47.0->google-genai)
#   Using cached google_auth-2.48.0-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (0.28.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.9.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (2.12.0)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (2.32.5)
# Requirement already satisfied: tenacity<9.2.0,>=8.2.3 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (9.1.2)
# Requirement already satisfied: websockets<15.1.0,>=13.0.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (15.0.1)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.11.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (4.15.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (1.9.0)
# Requirement already satisfied: sniffio in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (1.3.1)
# Requirement already satisfied: aiohttp>=3.10.11 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-genai) (3.13.1)
# Requirement already satisfied: idna>=2.8 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from anyio<5.0.0,>=4.8.0->google-genai) (3.10)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (46.0.5)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (4.9.1)
# Requirement already satisfied: certifi in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from httpx<1.0.0,>=0.28.1->google-genai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (2.41.1)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from pydantic<3.0.0,>=2.9.0->google-genai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from requests<3.0.0,>=2.28.1->google-genai) (2.5.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (0.6.1)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from aiohttp>=3.10.11->google-genai) (1.22.0)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\shels\documents\wezareit el dakhleya\.venv\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai) (3.0)
# Downloading google_genai-1.64.0-py3-none-any.whl (728 kB)
#    ---------------------------------------- 0.0/728.8 kB ? eta -:--:--
#    ---------------------------- ----------- 524.3/728.8 kB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 728.8/728.8 kB 3.3 MB/s  0:00:00
# Using cached google_auth-2.48.0-py3-none-any.whl (236 kB)
# Installing collected packages: google-auth, google-genai
#
#   Attempting uninstall: google-auth
#
#     Found existing installation: google-auth 2.41.1
#
#     Uninstalling google-auth-2.41.1:
#
#       Successfully uninstalled google-auth-2.41.1
#
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#    ---------------------------------------- 0/2 [google-auth]
#   Attempting uninstall: google-genai
#    ---------------------------------------- 0/2 [google-auth]
#     Found existing installation: google-genai 1.42.0
#    ---------------------------------------- 0/2 [google-auth]
#     Uninstalling google-genai-1.42.0:
#    ---------------------------------------- 0/2 [google-auth]
#       Successfully uninstalled google-genai-1.42.0
#    ---------------------------------------- 0/2 [google-auth]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    -------------------- ------------------- 1/2 [google-genai]
#    ---------------------------------------- 2/2 [google-genai]
#
# Successfully installed google-auth-2.48.0 google-genai-1.64.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai
from google.genai import types
import os
# Configure the client with API key
api_key = "AIzaSyB37Oz2Bf4OQ4so2RIW7ELSybMFXl8--LM"

# %%
# Only for videos of size <20Mb
video_file_name = "C:\\Users\\shels\\Downloads\\dakhleya videos\\women brutality stairs\\women brutality stairs.mp4"
video_bytes = open(video_file_name, 'rb').read()

client = genai.Client(api_key=api_key)
response = client.models.generate_content(
    model='models/gemini-2.5-flash',
    contents=types.Content(
        parts=[
            types.Part(
                inline_data=types.Blob(data=video_bytes, mime_type='video/mp4')
            ),
            types.Part(text='Give a detailed description of the video and what happens in it')
        ]
    )
)

# %%
print(response.text)
# Out:
# This video, captured by a security camera on August 17, 2025, at approximately 00:35:59, depicts a violent and chaotic domestic dispute unfolding in a stairwell.
#
# Here's a detailed breakdown of the events:
#
# *   **0:00 - 0:01:** The scene begins at the top of a stairwell. A man in a white t-shirt and dark pants, with a beard, is seen struggling with a woman dressed in a dark green top and pants. He appears to be holding her from behind and attempting to push her down the stairs. Loud shouting and what sounds like a struggle can be heard.
# *   **0:01 - 0:02:** The man forcefully shoves the woman, and both tumble down the first flight of stairs, landing on a small landing below. A loud thud or crash is heard. The man continues to grapple with the woman on the ground.
# *   **0:02 - 0:03:** As they are on the landing, another man, also in a white t-shirt (with "SWOSH BY NIKE" printed on it) and dark shorts, runs up the lower flight of stairs. He immediately confronts the first man. The woman in green is still on the ground, trying to get up.
# *   **0:03 - 0:05:** A physical altercation breaks out between the two men on the landing. The second man (Nike shirt) appears to gain the upper hand, pushing the first man (white shirt) further down the stairs. The woman in green scrambles away from the immediate fight zone.
# *   **0:05 - 0:07:** The second man (Nike shirt) continues to attack the first man, who falls completely down the remaining steps to the bottom floor. The sounds of shouting and what sounds like crying intensify.
# *   **0:07 - 0:11:** The second man (Nike shirt) follows the first man to the bottom of the stairs and proceeds to repeatedly kick and stomp on him while he is on the ground. The woman in green slowly starts to descend the stairs, looking distressed.
# *   **0:11 - 0:14:** A second woman, wearing a light blue top and a dark hijab/scarf, rushes into the frame from the bottom, appearing to come from an apartment or another area. She immediately sees the scene and runs towards the men, seemingly trying to intervene or separate them. A young boy and a young girl also appear, running down the stairs, observing the distressing scene. The video ends with multiple people gathered at the bottom of the stairs amidst the ongoing commotion.
#
# The Arabic text overlay "ايه اللي بيحصل ده !!!!" translates to "What is happening here!!!!", reflecting the shock and disbelief likely felt by anyone witnessing such an event. The video clearly captures a violent confrontation involving multiple individuals and children, indicating a serious domestic incident.

# %%
import time
from google import genai
from google.genai import types

client = genai.Client(api_key=api_key)

# 1. Upload using raw string (r"") to handle Windows backslashes
video_file = client.files.upload(file=r"C:/Users/shels/Documents/wezareit el dakhleya/dakhleyaVideos/women brutality stairs/women brutality stairs.mp4")

# 2. WAIT for the video to be processed (Required)
print(f"Uploading and processing {video_file.name}...")
while video_file.state.name == "PROCESSING":
    time.sleep(2)
    video_file = client.files.get(name=video_file.name)

if video_file.state.name == "FAILED":
    raise ValueError("Video processing failed.")

# 3. Analyze using Gemini 3 structure
response = client.models.generate_content(
    model='gemini-3-flash-preview',
    contents=[
        video_file,
        "analyze the video and give me detailed description of what happens in it"
    ],
    config=types.GenerateContentConfig(
        temperature=1.0, # Recommended for Gemini 3 reasoning models
        # Use types.MediaResolution.HIGH for "Original" quality 
        # Or types.MediaResolution.UNSPECIFIED for "Automatic"
        media_resolution=types.MediaResolution.MEDIA_RESOLUTION_MEDIUM, 
        response_mime_type="application/json"
    )
)

print(response.text)
# Out:
# Uploading and processing files/sknfh0r8sxbg...
# Warning: there are non-text parts in the response: ['thought_signature'], returning concatenated text result from text parts. Check the full candidates.content.parts accessor to get the full model response.
# [
#   {
#     "start_time": "00:00",
#     "end_time": "00:02",
#     "description": "A man in a white t-shirt is seen forcefully dragging a woman in green down a staircase while she screams and resists."
#   },
#   {
#     "start_time": "00:02",
#     "end_time": "00:05",
#     "description": "Two other men intervene to try and stop the aggressor. One man in a white Nike t-shirt pulls at the attacker, and a younger man also joins in to help."
#   },
#   {
#     "start_time": "00:05",
#     "end_time": "00:08",
#     "description": "The struggle continues as the men try to pull the attacker away from the woman, who is now on the floor near a doorway."
#   },
#   {
#     "start_time": "00:08",
#     "end_time": "00:11",
#     "description": "The attacker continues to resist the other men and tries to grab the woman again, while the intervenors push him back."
#   },
#   {
#     "start_time": "00:11",
#     "end_time": "00:14",
#     "description": "More people, including a woman in a blue shirt and headscarf, come down the stairs to assist in stopping the violence and calming the situation."
#   }
# ]

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""[
#   {
#     "description": "The video captures a violent physical altercation on a staircase landing, recorded by a security camera. An older man in a white shirt is seen brutally attacking a woman dressed in green, pulling her hair and pinning her to the ground. Two younger men immediately step in to intervene, attempting to restrain the aggressor and pull him away from the woman. The struggle is intense, leading to a large wooden panel or door being knocked over. As the fight continues, two other women emerge from a nearby room to help protect the victim. Throughout the footage, the older man remains extremely aggressive, repeatedly trying to reach the woman while the others struggle to keep him back. The scene is one of intense conflict, with multiple people involved in a chaotic effort to stop the assault."
#   }
# ]""",
#             thought_signature=b'\x12\x86-\n\x83-\x01\xbe>\xf6\xfb\xce_Q\x95\x14\x8f\x19\xf6T\xa4z\xb2ry(\xd4x\x9cq\xe6\xa2\xc3, \xa39[\xad\x11,\x19\xae\xee&\xf7\xf3\xb7\xc8\x91xM\x9a\xc0\xbc\xfa\xd3>4\xc8\x02m\xcav\xb3\xa0;<W\xc6i\xc6\x86r\xca\xfc\xdf\x99 \x844\xf33\\\xfb\x97\x85\x93\x8eK\xc9\xe2\xc1\xba\xf8\x86\xe7...'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-3-flash-preview',
#   response_id='JXKbacSEGqCPxN8Pqe6m2QY',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=166,
#     prompt_token_count=1337,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.VIDEO: 'VIDEO'>,
#         token_count=1318
#       ),
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=19
#       ),
#     ],
#     thoughts_token_count=1257,
#     total_token_count=2760
#   )
# )
